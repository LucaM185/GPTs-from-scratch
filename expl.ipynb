# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %%
x = torch.arange(0, 10, 0.1)  # [0, 0.1, 0.2, ..., 9.9]
y = (x - 5) + torch.randn(100)  # y = (x - 5) + noise 
plt.scatter(x, y)  #  y = 1*x - 5
